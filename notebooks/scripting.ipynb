# %%
from descriptions.dataset import load_data
import pandas as pd

# %%
df = load_data()

# %%
from descriptions.modeling.preprocess import load_preprocessors
# Out:
# 2025-11-20 12:39:03.965 | INFO     | descriptions.config:<module>:11 - PROJ_ROOT path is: /Users/christianfullerton/Developer/Python Workspace/movie_genre_model

# %%
preprocessors = load_preprocessors()
print(preprocessors)
# Out:
# 2025-11-20 12:39:09.373 | INFO     | descriptions.modeling.preprocess:load_preprocessors:115 - Loading fitted TfidfVectorizer from /Users/christianfullerton/Developer/Python Workspace/movie_genre_model/models/tfidf_vectorizer.joblib...
# 2025-11-20 12:39:09.386 | INFO     | descriptions.modeling.model:load_model:99 - Loading model from /Users/christianfullerton/Developer/Python Workspace/movie_genre_model/models/tfidf_vectorizer.joblib...
# 2025-11-20 12:39:09.482 | SUCCESS  | descriptions.modeling.model:load_model:101 - Model loaded successfully from /Users/christianfullerton/Developer/Python Workspace/movie_genre_model/models/tfidf_vectorizer.joblib
# 2025-11-20 12:39:09.482 | INFO     | descriptions.modeling.preprocess:load_preprocessors:118 - Loading fitted MultiLabelBinarizer from /Users/christianfullerton/Developer/Python Workspace/movie_genre_model/models/genre_binarizer.joblib...
# ...

# %%
tdidf_vectorizer, mlb = preprocessors
print(tdidf_vectorizer)
# Out:
# ['00', '000', '000th', '006', '007', '01', '10', '100', '1000', '1001', '100th', '101', '1021', '103', '108', '10s', '10th', '11', '111', '1123', '1138', '114', '117', '118', '118th', '119', '11th', '12', '120', '1200', '1215', '1250', '12th', '13', '130', '1347', '13th', '14', '140', '1408', '141', '1415', '142', '1429', '1492', '14pm', '14th', '15', '150', '1536', '155', '1561', '1562', '1572', '1596', '15th', '16', '1600', '1600s', '161', '1630', '165', '1666', '1681', '1692', '16th', '17', '1700s', '1743', '1755', '17th', '18', '1800', '1800s', '1809', '1812', '1818', '1820', '1820s', '1825', '1827', '1830', '1830s', '1831', '1839', '1840s', '1841', '1843', '1844', '1847', '1850', '1851', '1856', '1858', '1859', '1860', '1860s', '1862', '1863', '1865', '1868', '1870s', '1874', '1879', '1880s', '1885', '1889', '1890', '1890s', '1892', '1894', '1897', '18th', '19', '1900', '1900s', '1901', '1904', '1905', '1906', '1909', '1910', '1910s', '1912', '1913', '1914', '1916', '1918', '191
# ...
